# %%
import matplotlib.pyplot as plt # mat plot lib
import seaborn as sns # sea born
import pandas as pd
import numpy as np

# %%
sample = pd.read_csv('/content/Sample Dataset.csv')

#print(sample)

# %%
sample=pd.DataFrame(sample)
sample
# Out:
#     Machine Learning  NLP  AI Section
# 0                 11   16   7       A
# 1                  7   16  10       A
# 2                 18   17  13       A
# 3                  8   18  15       A
# 4                 10   11  18       A
# 5                  7   12   8       A
# 6                 13   10  10       A
# 7                  9    9  15       A
# 8                 17   11  18       A
# 9                 12   12   9       A
# 10                13    8  12       A
# 11                15   13  13       A
# 12                10   12  10       A
# 13                15   11   7       A
# 14                10   12  12       B
# 15                16    9   6       B
# 16                 8    9  16       B
# 17                15    8   8       B
# 18                 7   10   6       B
# 19                13    6  18       B
# 20                16   14  10       B
# 21                 6   12  14       B
# 22                13   11   8       B
# 23                 6    8  10       B
# ...

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# **Line Graph**

# %%
x = np.linspace(0,20)
y = x**3+10
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0,20)
y= x**2
plt.plot(x, y)
plt.xlabel('x-values')
plt.ylabel('x^2-values')
plt.title('Fig. 1 Line GRaph ')
plt.grid(True)
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
sample.plot(kind='scatter', x='NLP', y='AI') 
plt.show()

# %%
sample.plot(kind='scatter', x='NLP', y='AI',color='green',grid='True',title='Scatter Plot') 
plt.show()

# %%
colours = {'A':'orange', 'B':'green', 'C':'blue'}
for i in range(len(sample['Machine Learning'])):
  plt.scatter(sample['NLP'][i],sample['AI'][i], color = colours[sample['Section'][i]])
plt.title('Scatter Plot')
plt.xlabel('NLP')
plt.ylabel('AI')
plt.grid(True)
plt.show()

# %% [markdown]
# **Bar plots**

# %%
a= sample['Section'].value_counts()
# Types
section_names = a.index
# Each Type Count
count = a.values
plt.bar(section_names,count,color = 'lightgreen')
plt.xlabel('section_names')
plt.ylabel('count')
plt.show()

# %% [markdown]
# **Box Plot**

# %%
length_width = df[['Machine Learning','NLP','AI']] #excluding species column
length_width.boxplot()
plt.xlabel('Course')
plt.ylabel('values')
plt.title("Sample Dataset analysis")
plt.show()

# %% [markdown]
# **Pie Charts**

# %%
a= sample['Section'].value_counts()
section_names = a.index
count = a.values
colors= ['lightblue','lightgreen','gold']
explode = (0,0,.6)
#explode = (0,.6,0)
plt.pie(count, labels=section_names,shadow=True,
        colors=colors,explode = explode, autopct='%1.1f%%')
plt.xlabel('section_names')
plt.axis('equal')
plt.show()
