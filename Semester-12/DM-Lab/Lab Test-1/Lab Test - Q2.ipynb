# %%
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

# %%
eva = pd.read_csv(r"/content/Evaluation 2 Dataset.csv")
#eva.head()
#eva
eva_1=pd.DataFrame(eva)
eva_1
# Out:
#     StudentID   OOP  Database  Data Mining  CGPA
# 0      202101  24.0      27.0         20.0  3.56
# 1      202102  25.0      18.0         25.0  3.27
# 2      202103  24.0      15.0         19.0  3.24
# 3      202104  23.0      20.0         25.0  3.54
# 4      202105   NaN      20.0          NaN  3.20
# 5      202106  27.0      18.0         23.0  3.32
# 6      202107  23.0      20.0         15.0   NaN
# 7      202108  23.0      22.0         30.0  3.32
# 8      202109  24.0      17.0         17.0  3.77
# 9      202110  25.0      21.0         23.0  3.72
# 10     202111  27.0       NaN         19.0  3.53
# 11     202112  28.0      20.0         18.0  3.21
# 12     202113   NaN      16.0         27.0  3.30
# 13     202114  24.0      25.0         17.0  3.32
# 14     202115  21.0      20.0          9.0  3.76
# 15     202116   9.0      20.0         19.0  3.39
# 16     202117  21.0      23.0         20.0  3.59
# 17     202118  22.0      23.0         25.0  3.60
# ...

# %%
eva_1=eva_1.copy()
eva_1.isnull().sum()
# Out:
# StudentID      0
# OOP            2
# Database       2
# Data Mining    2
# CGPA           3
# dtype: int64

# %% [markdown]
# **Get Frequent values**

# %%
print(eva_1['OOP'].mode())
print(eva_1['Database'].mode())
print(eva_1['Data Mining'].mode())
print(eva_1['CGPA'].mode())
# Out:
# 0    24.0
# dtype: float64
# 0    20.0
# dtype: float64
# 0    21.0
# dtype: float64
# 0    3.32
# dtype: float64

# %% [markdown]
# **Fill up with frequent values**

# %%
#eva_1['Data Mining'].fillna(eva_1['Data Mining'].mode()[0], inplace=True)
#eva_1['OOP'].fillna(eva_1['OOP'].mode()[0], inplace=True)
#eva_1['Database'].fillna(eva_1['Database'].mode()[0], inplace=True)
#eva_1['CGPA'].fillna(eva_1['CGPA'].mode()[0], inplace=True)
#eva_1

eva_1['Data Mining'].fillna(eva_1['Data Mining'].replace(10), inplace=True)
eva_1['OOP'].fillna(eva_1['OOP'].replace(10), inplace=True)
eva_1['Database'].fillna(eva_1['Database'].replace(10), inplace=True)
eva_1['CGPA'].fillna(eva_1['CGPA'].replace(10), inplace=True)
#eva_1

# %% [markdown]
# Removing outliers

# %%
data_without_missing_values_1 = pd.DataFrame(eva_1)
data_without_missing_values_1
 
 
data_without_missing_values_2 = data_without_missing_values_1.copy()
data_without_missing_values_2.isnull().sum()
 
q1 =data_without_missing_values_1['CGPA'].quantile(0.998) #other than outlier
 
q4 =data_without_missing_values_1['CGPA'].quantile(0.0013) #outlier
 
data_without_outlier_top = data_without_missing_values_1[data_without_missing_values_1['CGPA']<q1]
 
data_without_outlier = data_without_outlier_top[data_without_outlier_top['CGPA']>q4]
 
data_without_outlier
# Out:
#     StudentID   OOP  Database  Data Mining  CGPA
# 0      202101  24.0      27.0         20.0  3.56
# 1      202102  25.0      18.0         25.0  3.27
# 2      202103  24.0      15.0         19.0  3.24
# 3      202104  23.0      20.0         25.0  3.54
# 5      202106  27.0      18.0         23.0  3.32
# 7      202108  23.0      22.0         30.0  3.32
# 8      202109  24.0      17.0         17.0  3.77
# 9      202110  25.0      21.0         23.0  3.72
# 10     202111  27.0       NaN         19.0  3.53
# 11     202112  28.0      20.0         18.0  3.21
# 12     202113   NaN      16.0         27.0  3.30
# 13     202114  24.0      25.0         17.0  3.32
# 14     202115  21.0      20.0          9.0  3.76
# 15     202116   9.0      20.0         19.0  3.39
# 16     202117  21.0      23.0         20.0  3.59
# 17     202118  22.0      23.0         25.0  3.60
# 18     202119  21.0      15.0         22.0  3.40
# 19     202120  23.0      18.0          NaN  3.69
# ...
